# %% [markdown]
# # Project 2 - Medical Imaging

# %% [markdown]
# ## Imports

# %%
import os 
import re 

import numpy as np 
import pandas as pd 
from PIL import Image 
from matplotlib import pyplot as plt 
import seaborn as sns 

from skimage import morphology 
from skimage.transform import rotate 


from time import time

# %% [markdown]
# ## Global Variables

# %%
# Initial parameters for running the notebook 
PREPROCESS = False
COMPUTE_FEATURES = True

# %%
# Paths to directories used 

ROOT_DIR = "../"
DATA_DIR = ROOT_DIR + "data"
IM_DIR = DATA_DIR + "/ISIC-2017_Training_Data"
MASK_DIR = DATA_DIR + "/ISIC-2017_Training_Part1_GroundTruth"
DIAGNOSIS_PATH = DATA_DIR + "/ISIC-2017_Training_Part3_GroundTruth.csv"

# %%
# Load all filenames into a dictionary
FILENAMES = {}
FILENAMES['images'] = sorted([IM_DIR + "/" + i for i in list(os.walk(IM_DIR))[0][2]])
FILENAMES['masks'] = sorted([f"{MASK_DIR}/{i}" for i in list(os.walk(MASK_DIR))[0][2]])
FILENAMES['image_num'] = len(FILENAMES['images'])

# %% [markdown]
# ## Helper functions

# %%
def make_sides_even(image): 
    '''
    Function to make the numbers of columns and rows in 
    an image even. 
    Input: An image 
    Output: An image
    '''
    # Convert image to numpy array
    image = np.array(image)
    
    # Check if the number of rows is even 
    if image.shape[0] % 2 != 0: 
        # Delete the first row
        image = np.delete(image,0,axis = 0)
    
    # Check if the number of columns is even 
    if image.shape[1] % 2 != 0: 
        # Delete the first column
        image = np.delete(image,0,axis = 1)
    
    # Convert numpy array back to image 
    image = Image.fromarray(image)
    # Return the updated image 
    return image

# %%
def filter_and_crop_image(image_path,mask_path): 
    '''
    Function to filter filter an image based on a given mask 
    and crop both image and mask to the relevant area. 
    '''
    # Instantiate both image and mask 
    image = Image.open(image_path) 
    mask = Image.open(mask_path)
    
    # Crop both image and mask to the bounding box
    # of the mask. 
    image_crop = image.crop(mask.getbbox())
    mask_crop = mask.crop(mask.getbbox())
    
    # Make the length and height of the the image and 
    # mask even 
    image_crop = make_sides_even(image_crop)
    mask_crop = make_sides_even(mask_crop)

    # Instantiate a blank image for a composite image
    tmp_image = Image.new("RGB",image_crop.size, 0)

    # Create a composite image based on the blank image, 
    # the cropped image and the mask 
    filtered_image = Image.composite(image_crop,tmp_image,mask_crop)
    
    # Return the filtered image, the cropped mask and the cropped image 
    return filtered_image, mask_crop, image_crop

# %% [markdown]
# ## Preprocessing

# %%
# Check if the PREPROCESS variable is True 
if PREPROCESS: 
    # Try to create directories for the filtered images, cropped masks 
    # and cropped images 
    try: 
        os.makedirs(DATA_DIR + "/filtered_images")
        os.makedirs(DATA_DIR + "/filtered_masks")
        os.makedirs(DATA_DIR + "/cropped_images")

    except FileExistsError:
        print("Directories exist")
    except IsADirectoryError: 
        print("Directories exist")

    # Instantiate variables containing the paths to the filtered images, 
    # cropped masks and cropped images 
    IMAGE_FILTER_DIR = DATA_DIR + "/filtered_images"
    MASK_FILTER_DIR = DATA_DIR + "/filtered_masks"
    IMAGE_CROP_DIR = DATA_DIR + "/cropped_images"

    # Loop over all images and masks based on the number of images
    for i in range(FILENAMES['image_num']):
        # Instantiate variables with the paths to the currently processing image
        # and mask 
        mask_path = FILENAMES['masks'][i]
        image_path = FILENAMES['images'][i]

        # Filter and crop the image and mask 
        image, mask, crop = filter_and_crop_image(image_path,mask_path)

        # Instantiate variables containing the image and mask name 
        image_name = image_path.split("/")[-1].split(".")[-2]
        mask_name = mask_path.split("/")[-1].split(".")[-2]

        # Save the generated images and mask to files 
        image.save(IMAGE_FILTER_DIR + "/" + image_name + ".jpg")
        mask.save(MASK_FILTER_DIR + "/" + mask_name + ".png")
        crop.save(IMAGE_CROP_DIR + "/" + image_name + ".jpg")

        # Clear the temporary variables 
        del mask_path, image_path, image, mask, crop, image_name, mask_name
    
    # Load all the new filenames into the FILENAMES dictionary
    FILENAMES['filtered_images'] = sorted([f"{IMAGE_FILTER_DIR}/{i}" for i in list(os.walk(IMAGE_FILTER_DIR))[0][2]])
    FILENAMES['cropped_images'] = sorted([f"{IMAGE_CROP_DIR}/{i}" for i in list(os.walk(IMAGE_CROP_DIR))[0][2]])
    FILENAMES['cropped_masks'] = sorted([f"{MASK_FILTER_DIR}/{i}" for i in list(os.walk(MASK_FILTER_DIR))[0][2]])
else: 
    # Instantiate variables containing the paths to the filtered images, 
    # cropped masks and cropped images 
    IMAGE_FILTER_DIR = DATA_DIR + "/filtered_images"
    MASK_FILTER_DIR = DATA_DIR + "/filtered_masks"
    IMAGE_CROP_DIR = DATA_DIR + "/cropped_images"

    # Load all the new filenames into the FILENAMES dictionary
    FILENAMES['filtered_images'] = sorted([f"{IMAGE_FILTER_DIR}/{i}" for i in list(os.walk(IMAGE_FILTER_DIR))[0][2]])
    FILENAMES['cropped_images'] = sorted([f"{IMAGE_CROP_DIR}/{i}" for i in list(os.walk(IMAGE_CROP_DIR))[0][2]])
    FILENAMES['cropped_masks'] = sorted([f"{MASK_FILTER_DIR}/{i}" for i in list(os.walk(MASK_FILTER_DIR))[0][2]])

# %% [markdown]
# ## Feature Extraction Functions

# %%
## Find the area and perimeter of the mask 
def get_area_perimeter(mask): 
    '''
    Function which takes in a mask for a
    given image and returns the area and 
    perimeter of the mask. 
    '''

    # Convert the mask to a Numpy array containing 1's and 0's
    mask = np.where(np.array(mask) ==255,1,0)

    # Calculate the area of the mask as the sum of the Numpy array
    area = np.sum(mask)
    
    # Erode the edge of the mask in order to calculate the perimeter 
    perimeters = []
    for i in range(1,5):
        mask_erosion = morphology.binary_erosion(mask,morphology.disk(i))
        
        # Calculate the perimeter 
        perimeter = np.sum(mask - mask_erosion)
        perimeters.append(perimeter)
    # Return the area and the perimeter 
    return area, perimeters

# %%
def get_compactness(mask): 
    '''
    Function which takes in a mask for a given 
    image, calls the get_area_perimeter function
    to get the area and perimeter, and returns a 
    compactness score based upon [CITATION NEEDED]. 
    '''
    # Calculate the area and the perimeter 
    area, perimeters = get_area_perimeter(mask) 
    compactness_list = []
    for i in perimeters: 

    # Calculate the compactness 
        compactness = i ** 2 / (4 * np.pi * area)
        compactness_list.append(compactness)
    # Return the compactness 
    compactness = compactness_list 
    return compactness

# %%
def get_asymmetry(mask, rotation=45): 
    '''
    Takes in a mask for a given image, rotates it 
    180 times by one degree, compares the left and 
    right half and returns an average asymmetry score.
    '''
    # Instantiate the mask as a Numpy array 
    mask = np.array(mask)
    axes = 0 
    # Get the length and width of the mask 
    length, width = mask.shape 
    # Define a number of pixels for padding to avoid information loss
    # pad_size = int(max((length, width))/)
    
    # Redefine the length to include the padded pixels 
    # length = length + 2 * pad_size 
    # Pad the mask 
    # mask = np.pad(mask,pad_size)
    
    # Instantiate a list to holds the calculated differences  
    diffs = []

    while axes * rotation < 180:
        temp_mask = rotate(mask, axes * rotation)
        # length_lesion = np.nonzero(np.sum(temp_mask, axis = 0))[0][-1] - np.nonzero(np.sum(temp_mask, axis = 0))[0][0]

        left_mask = temp_mask[:, :int(length/2)] 
        right_mask = temp_mask[:, int(length/2):]
        right_mask = np.fliplr(right_mask)
        rotation_diff = np.where(left_mask != right_mask)
    
        diffs.append(np.sum(rotation_diff))
        
        axes += 1
    
    diff = np.mean(diffs)
    
    return diff

# %%
def get_average_luminance(image): 
    '''
    A function which takes in an image and
    returns the average luminance. 
    Input: A PIL Image 
    Output: Average luminance of the image
    '''
    # Convert the image to grayscale and then to a Numpy array 
    grayscale = np.array(image.convert('L'))

    # Calculate the mean of the luminance
    average_luminance = round(np.mean(grayscale[grayscale > 0]))

    # Return the average luminance 
    return average_luminance

# %%
def get_luminance_variability(image,measure="variance"): 

    # Convert the image to grayscale and then to a Numpy array 
    grayscale = np.array(image.convert('L'))

    # Check if measure is 'variance'
    if measure == 'variance': 
        # Using numpy's variance method, return the variance in luminance
        return round(np.var(grayscale[grayscale > 0]))
    # Check if measure is 'standard_deviation'
    elif measure == "standard_deviation": 
        # Using numpy's standard deviation method, return the standard deviation
        return round(np.std(grayscale[grayscale > 0]))
    else: 
        # If measure is neither 'variance' nor 'standard_deviation', raise a 
        # ValueError. 
        raise ValueError("Only 'variance' or 'standard_deviation' accepted.")

# %%
def get_avg_color(image): 
    '''
    A function which takes in an image and returns 
    the average color of the image. 
    '''
    # Split the image into separate color channels 
    r, g, b = image.split()
    # Instantiate a numpy array based on each color channel 
    r = np.array(r)
    g = np.array(g)
    b = np.array(b)
    # Calculate the mean of each color channel 
    average_color = (
        round(np.mean(r[r > 0])), 
        round(np.mean(g[g > 0])), 
        round(np.mean(b[b > 0]))
    )
    # Return a tuple of the average color 
    return average_color

# %%
def get_color_variance(image,measure="variance"): 
    '''
    A function which takes in an image and 
    returns the variance of the color. 
    '''
    # Split the image into separate color channels 
    r, g, b = image.split()
    # Instantiate a numpy array based on each color channel 
    r = np.array(r)
    g = np.array(g)
    b = np.array(b)
    # Check if measure is 'variance'
    if measure == "variance": 
        # Using numpy's variance method, calculate the variance of each color
        rgb = (
            np.var(r[r>0]),
            np.var(g[g>0]),
            np.var(b[b>0])
        )
    # Check if measure is 'standard_deviation'
    elif measure == "standard_deviation": 
        # Using numpy's standard deviation method, calculate the standard deviation
        # of each color 
        rgb = (
            np.std(r[r>0]),
            np.std(g[g>0]),
            np.std(b[b>0])
        )
    else: 
        # If measure is neither 'variance' nor 'standard_deviation', raise 
        # a ValueError 
        raise ValueError("Only 'variance' or 'standard_deviation' accepted.") 
    # Return the mean of the variances or standard deviation of the 3 colors
    return np.mean(rgb)

# %% [markdown]
# ## Feature Extraction

# %%
# Check if the COMPUTE_FEATURES variable is True 
if COMPUTE_FEATURES: 
    # Instantiate a dictionary to store the features and image_id's 
    # feature_dictionary = {
    #     "image_id": [],
    #     "area": [], 
    #     "perimeter": [],
    #     "compactness": [], 
    #     "asymmetry": [], 
    #     "luminance_average": [],
    #     "luminance_variance": [],
    #     "red_average": [],
    #     "green_average": [],
    #     "blue_average": [],
    #     "color_variance": [],
    # }
    feature_dictionary = {
        "image_id": [],
        "area": [], 
        "perimeter_1": [],
        "perimeter_2": [],
        "perimeter_3": [],
        "perimeter_4": [],
        
        "compactness_1": [],
        "compactness_2": [],
        "compactness_3": [],
        "compactness_4": [], 
        "asymmetry": [], 
        "luminance_average": [],
        "luminance_variance": [],
        "red_average": [],
        "green_average": [],
        "blue_average": [],
        "color_variance": [],
    }

    # Loop over all filtered images and cropped masks 
    for i in range(FILENAMES['image_num']): 
        # Instantiate variables containing the paths to the image and mask
        filtered_image_path = FILENAMES['filtered_images'][i]
        cropped_mask_path = FILENAMES['cropped_masks'][i]

        # Get the image name from the image path 
        image_name = filtered_image_path.split("/")[-1].split(".")[-2]

        print(f"Currently working on {i} - Image id: {image_name}")

        # Open both the image and mask as PIL Images 
        filtered_image = Image.open(filtered_image_path)
        cropped_mask = Image.open(cropped_mask_path)

        # Calculate all features and append them to the relevant list in 
        # the feature_dictionary 
        feature_dictionary['image_id'].append(image_name)
        area, perimeter = get_area_perimeter(cropped_mask)
        feature_dictionary['area'].append(area)
        
        feature_dictionary['perimeter_1'].append(perimeter[0])
        feature_dictionary['perimeter_2'].append(perimeter[1])
        feature_dictionary['perimeter_3'].append(perimeter[2])
        feature_dictionary['perimeter_4'].append(perimeter[3])
        compactness = get_compactness(cropped_mask)
        feature_dictionary['compactness_1'].append(compactness[0])
        feature_dictionary['compactness_2'].append(compactness[1])
        feature_dictionary['compactness_3'].append(compactness[2])
        feature_dictionary['compactness_4'].append(compactness[3])


        # feature_dictionary['compactness'].append(get_compactness(cropped_mask))

    
        feature_dictionary['asymmetry'].append(get_asymmetry(cropped_mask))
        feature_dictionary['luminance_average'].append(get_average_luminance(filtered_image))
        feature_dictionary['luminance_variance'].append(get_luminance_variability(filtered_image))
        red, green, blue = get_avg_color(filtered_image)
        feature_dictionary['red_average'].append(red)
        feature_dictionary['green_average'].append(green)
        feature_dictionary['blue_average'].append(blue)
        feature_dictionary['color_variance'].append(get_color_variance(filtered_image))
    # Instantiate a pandas DataFrame based on the feature_dictionary
    features = pd.DataFrame(feature_dictionary)
    # Write the features DataFrame to .csv 
    features.to_csv(ROOT_DIR + "/features/feature_set.csv",sep=";",index=False)
else: 
    # Read the previously calculated feature set into a pandas DataFrame 
    features = pd.read_csv(ROOT_DIR + "/features/feature_set.csv", sep=";", index_col=False)
# Out:
# Currently working on 0 - Image id: ISIC_0000000
# Currently working on 1 - Image id: ISIC_0000001
# Currently working on 2 - Image id: ISIC_0000002
# Currently working on 3 - Image id: ISIC_0000003
# Currently working on 4 - Image id: ISIC_0000004
# Currently working on 5 - Image id: ISIC_0000006
# Currently working on 6 - Image id: ISIC_0000007
# Currently working on 7 - Image id: ISIC_0000008
# Currently working on 8 - Image id: ISIC_0000009
# Currently working on 9 - Image id: ISIC_0000010
# Currently working on 10 - Image id: ISIC_0000011
# Currently working on 11 - Image id: ISIC_0000012
# Currently working on 12 - Image id: ISIC_0000013
# Currently working on 13 - Image id: ISIC_0000014
# Currently working on 14 - Image id: ISIC_0000015
# Currently working on 15 - Image id: ISIC_0000016
# Currently working on 16 - Image id: ISIC_0000017
# Currently working on 17 - Image id: ISIC_0000018
# Currently working on 18 - Image id: ISIC_0000019
# Currently working on 19 - Image id: ISIC_0000020
# Currently working on 20 - Image id: ISIC_0000021
# Currently working on 21 - Image id: ISIC_0000022
# Currently working on 22 - Image id: ISIC_0000023
# Currently working on 23 - Image id: ISIC_0000024
# Currently working on 24 - Image id: ISIC_0000025
# Currently working on 25 - Image id: ISIC_0000026
# Currently working on 26 - Image id: ISIC_0000027
# Currently working on 27 - Image id: ISIC_0000028
# Currently working on 28 - Image id: ISIC_0000029
# Currently working on 29 - Image id: ISIC_0000030
# Currently working on 30 - Image id: ISIC_0000031
# Currently working on 31 - Image id: ISIC_0000032
# Currently working on 32 - Image id: ISIC_0000034
# Currently working on 33 - Image id: ISIC_0000035
# Currently working on 34 - Image id: ISIC_0000036
# Currently working on 35 - Image id: ISIC_0000037
# Currently working on 36 - Image id: ISIC_0000038
# Currently working on 37 - Image id: ISIC_0000039
# Currently working on 38 - Image id: ISIC_0000040
# Currently working on 39 - Image id: ISIC_0000041
# Currently working on 40 - Image id: ISIC_0000042
# Currently working on 41 - Image id: ISIC_0000043
# Currently working on 42 - Image id: ISIC_0000044
# Currently working on 43 - Image id: ISIC_0000045
# Currently working on 44 - Image id: ISIC_0000046
# Currently working on 45 - Image id: ISIC_0000047
# Currently working on 46 - Image id: ISIC_0000048
# Currently working on 47 - Image id: ISIC_0000049
# Currently working on 48 - Image id: ISIC_0000050
# Currently working on 49 - Image id: ISIC_0000051
# Currently working on 50 - Image id: ISIC_0000052
# Currently working on 51 - Image id: ISIC_0000053
# Currently working on 52 - Image id: ISIC_0000054
# Currently working on 53 - Image id: ISIC_0000055
# Currently working on 54 - Image id: ISIC_0000056
# Currently working on 55 - Image id: ISIC_0000057
# Currently working on 56 - Image id: ISIC_0000059
# Currently working on 57 - Image id: ISIC_0000061
# Currently working on 58 - Image id: ISIC_0000062
# Currently working on 59 - Image id: ISIC_0000063
# Currently working on 60 - Image id: ISIC_0000064
# Currently working on 61 - Image id: ISIC_0000065
# Currently working on 62 - Image id: ISIC_0000066
# Currently working on 63 - Image id: ISIC_0000067
# Currently working on 64 - Image id: ISIC_0000068
# Currently working on 65 - Image id: ISIC_0000069
# Currently working on 66 - Image id: ISIC_0000071
# Currently working on 67 - Image id: ISIC_0000072
# Currently working on 68 - Image id: ISIC_0000073
# Currently working on 69 - Image id: ISIC_0000074
# Currently working on 70 - Image id: ISIC_0000075
# Currently working on 71 - Image id: ISIC_0000077
# Currently working on 72 - Image id: ISIC_0000078
# Currently working on 73 - Image id: ISIC_0000079
# Currently working on 74 - Image id: ISIC_0000080
# Currently working on 75 - Image id: ISIC_0000081
# Currently working on 76 - Image id: ISIC_0000082
# Currently working on 77 - Image id: ISIC_0000085
# Currently working on 78 - Image id: ISIC_0000086
# Currently working on 79 - Image id: ISIC_0000087
# Currently working on 80 - Image id: ISIC_0000088
# Currently working on 81 - Image id: ISIC_0000089
# Currently working on 82 - Image id: ISIC_0000091
# Currently working on 83 - Image id: ISIC_0000092
# Currently working on 84 - Image id: ISIC_0000093
# Currently working on 85 - Image id: ISIC_0000094
# Currently working on 86 - Image id: ISIC_0000095
# Currently working on 87 - Image id: ISIC_0000096
# Currently working on 88 - Image id: ISIC_0000097
# Currently working on 89 - Image id: ISIC_0000098
# Currently working on 90 - Image id: ISIC_0000099
# Currently working on 91 - Image id: ISIC_0000100
# Currently working on 92 - Image id: ISIC_0000101
# Currently working on 93 - Image id: ISIC_0000102
# Currently working on 94 - Image id: ISIC_0000103
# Currently working on 95 - Image id: ISIC_0000104
# Currently working on 96 - Image id: ISIC_0000105
# Currently working on 97 - Image id: ISIC_0000107
# Currently working on 98 - Image id: ISIC_0000108
# Currently working on 99 - Image id: ISIC_0000109
# Currently working on 100 - Image id: ISIC_0000110
# Currently working on 101 - Image id: ISIC_0000111
# Currently working on 102 - Image id: ISIC_0000112
# Currently working on 103 - Image id: ISIC_0000113
# Currently working on 104 - Image id: ISIC_0000116
# Currently working on 105 - Image id: ISIC_0000118
# Currently working on 106 - Image id: ISIC_0000119
# Currently working on 107 - Image id: ISIC_0000120
# Currently working on 108 - Image id: ISIC_0000121
# Currently working on 109 - Image id: ISIC_0000122
# Currently working on 110 - Image id: ISIC_0000123
# Currently working on 111 - Image id: ISIC_0000124
# Currently working on 112 - Image id: ISIC_0000125
# Currently working on 113 - Image id: ISIC_0000126
# Currently working on 114 - Image id: ISIC_0000127
# Currently working on 115 - Image id: ISIC_0000128
# Currently working on 116 - Image id: ISIC_0000129
# Currently working on 117 - Image id: ISIC_0000130
# Currently working on 118 - Image id: ISIC_0000131
# Currently working on 119 - Image id: ISIC_0000132
# Currently working on 120 - Image id: ISIC_0000133
# Currently working on 121 - Image id: ISIC_0000134
# Currently working on 122 - Image id: ISIC_0000135
# Currently working on 123 - Image id: ISIC_0000136
# Currently working on 124 - Image id: ISIC_0000137
# Currently working on 125 - Image id: ISIC_0000138
# Currently working on 126 - Image id: ISIC_0000139
# Currently working on 127 - Image id: ISIC_0000140
# Currently working on 128 - Image id: ISIC_0000141
# Currently working on 129 - Image id: ISIC_0000142
# Currently working on 130 - Image id: ISIC_0000143
# Currently working on 131 - Image id: ISIC_0000145
# Currently working on 132 - Image id: ISIC_0000146
# Currently working on 133 - Image id: ISIC_0000147
# Currently working on 134 - Image id: ISIC_0000148
# Currently working on 135 - Image id: ISIC_0000149
# Currently working on 136 - Image id: ISIC_0000150
# Currently working on 137 - Image id: ISIC_0000151
# Currently working on 138 - Image id: ISIC_0000152
# Currently working on 139 - Image id: ISIC_0000153
# Currently working on 140 - Image id: ISIC_0000154
# Currently working on 141 - Image id: ISIC_0000155
# Currently working on 142 - Image id: ISIC_0000156
# Currently working on 143 - Image id: ISIC_0000157
# Currently working on 144 - Image id: ISIC_0000159
# Currently working on 145 - Image id: ISIC_0000160
# Currently working on 146 - Image id: ISIC_0000161
# Currently working on 147 - Image id: ISIC_0000162
# Currently working on 148 - Image id: ISIC_0000163
# Currently working on 149 - Image id: ISIC_0000164
# Currently working on 150 - Image id: ISIC_0000165
# Currently working on 151 - Image id: ISIC_0000166
# Currently working on 152 - Image id: ISIC_0000167
# Currently working on 153 - Image id: ISIC_0000169
# Currently working on 154 - Image id: ISIC_0000171
# Currently working on 155 - Image id: ISIC_0000172
# Currently working on 156 - Image id: ISIC_0000174
# Currently working on 157 - Image id: ISIC_0000176
# Currently working on 158 - Image id: ISIC_0000177
# Currently working on 159 - Image id: ISIC_0000179
# Currently working on 160 - Image id: ISIC_0000181
# Currently working on 161 - Image id: ISIC_0000182
# Currently working on 162 - Image id: ISIC_0000184
# Currently working on 163 - Image id: ISIC_0000185
# Currently working on 164 - Image id: ISIC_0000186
# Currently working on 165 - Image id: ISIC_0000188
# Currently working on 166 - Image id: ISIC_0000189
# Currently working on 167 - Image id: ISIC_0000190
# Currently working on 168 - Image id: ISIC_0000191
# Currently working on 169 - Image id: ISIC_0000192
# Currently working on 170 - Image id: ISIC_0000193
# Currently working on 171 - Image id: ISIC_0000196
# Currently working on 172 - Image id: ISIC_0000197
# Currently working on 173 - Image id: ISIC_0000198
# Currently working on 174 - Image id: ISIC_0000199
# Currently working on 175 - Image id: ISIC_0000201
# Currently working on 176 - Image id: ISIC_0000202
# Currently working on 177 - Image id: ISIC_0000203
# Currently working on 178 - Image id: ISIC_0000204
# Currently working on 179 - Image id: ISIC_0000205
# Currently working on 180 - Image id: ISIC_0000206
# Currently working on 181 - Image id: ISIC_0000207
# Currently working on 182 - Image id: ISIC_0000208
# Currently working on 183 - Image id: ISIC_0000209
# Currently working on 184 - Image id: ISIC_0000211
# Currently working on 185 - Image id: ISIC_0000212
# Currently working on 186 - Image id: ISIC_0000213
# Currently working on 187 - Image id: ISIC_0000214
# Currently working on 188 - Image id: ISIC_0000215
# Currently working on 189 - Image id: ISIC_0000216
# Currently working on 190 - Image id: ISIC_0000217
# Currently working on 191 - Image id: ISIC_0000218
# Currently working on 192 - Image id: ISIC_0000219
# Currently working on 193 - Image id: ISIC_0000220
# Currently working on 194 - Image id: ISIC_0000221
# Currently working on 195 - Image id: ISIC_0000222
# Currently working on 196 - Image id: ISIC_0000223
# Currently working on 197 - Image id: ISIC_0000224
# Currently working on 198 - Image id: ISIC_0000225
# Currently working on 199 - Image id: ISIC_0000226
# Currently working on 200 - Image id: ISIC_0000227
# Currently working on 201 - Image id: ISIC_0000229
# Currently working on 202 - Image id: ISIC_0000231
# Currently working on 203 - Image id: ISIC_0000232
# Currently working on 204 - Image id: ISIC_0000233
# Currently working on 205 - Image id: ISIC_0000234
# Currently working on 206 - Image id: ISIC_0000235
# Currently working on 207 - Image id: ISIC_0000236
# Currently working on 208 - Image id: ISIC_0000237
# Currently working on 209 - Image id: ISIC_0000239
# Currently working on 210 - Image id: ISIC_0000240
# Currently working on 211 - Image id: ISIC_0000242
# Currently working on 212 - Image id: ISIC_0000243
# Currently working on 213 - Image id: ISIC_0000244
# Currently working on 214 - Image id: ISIC_0000245
# Currently working on 215 - Image id: ISIC_0000246
# Currently working on 216 - Image id: ISIC_0000247
# Currently working on 217 - Image id: ISIC_0000250
# Currently working on 218 - Image id: ISIC_0000251
# Currently working on 219 - Image id: ISIC_0000252
# Currently working on 220 - Image id: ISIC_0000253
# Currently working on 221 - Image id: ISIC_0000254
# Currently working on 222 - Image id: ISIC_0000255
# Currently working on 223 - Image id: ISIC_0000256
# Currently working on 224 - Image id: ISIC_0000258
# Currently working on 225 - Image id: ISIC_0000259
# Currently working on 226 - Image id: ISIC_0000260
# Currently working on 227 - Image id: ISIC_0000261
# Currently working on 228 - Image id: ISIC_0000262
# Currently working on 229 - Image id: ISIC_0000263
# Currently working on 230 - Image id: ISIC_0000264
# Currently working on 231 - Image id: ISIC_0000265
# Currently working on 232 - Image id: ISIC_0000268
# Currently working on 233 - Image id: ISIC_0000269
# Currently working on 234 - Image id: ISIC_0000274
# Currently working on 235 - Image id: ISIC_0000275
# Currently working on 236 - Image id: ISIC_0000276
# Currently working on 237 - Image id: ISIC_0000277
# Currently working on 238 - Image id: ISIC_0000278
# Currently working on 239 - Image id: ISIC_0000281
# Currently working on 240 - Image id: ISIC_0000282
# Currently working on 241 - Image id: ISIC_0000283
# Currently working on 242 - Image id: ISIC_0000285
# Currently working on 243 - Image id: ISIC_0000288
# Currently working on 244 - Image id: ISIC_0000289
# Currently working on 245 - Image id: ISIC_0000290
# Currently working on 246 - Image id: ISIC_0000292
# Currently working on 247 - Image id: ISIC_0000293
# Currently working on 248 - Image id: ISIC_0000294
# Currently working on 249 - Image id: ISIC_0000295
# Currently working on 250 - Image id: ISIC_0000297
# Currently working on 251 - Image id: ISIC_0000298
# Currently working on 252 - Image id: ISIC_0000299
# Currently working on 253 - Image id: ISIC_0000300
# Currently working on 320 - Image id: ISIC_0000382
# Currently working on 321 - Image id: ISIC_0000383
# Currently working on 322 - Image id: ISIC_0000384
# Currently working on 323 - Image id: ISIC_0000385
# Currently working on 324 - Image id: ISIC_0000386
# Currently working on 325 - Image id: ISIC_0000387
# Currently working on 326 - Image id: ISIC_0000388
# Currently working on 327 - Image id: ISIC_0000390
# Currently working on 328 - Image id: ISIC_0000391
# Currently working on 329 - Image id: ISIC_0000392
# Currently working on 330 - Image id: ISIC_0000393
# Currently working on 331 - Image id: ISIC_0000395
# Currently working on 332 - Image id: ISIC_0000396
# Currently working on 333 - Image id: ISIC_0000397
# Currently working on 334 - Image id: ISIC_0000403
# Currently working on 335 - Image id: ISIC_0000407
# Currently working on 336 - Image id: ISIC_0000408
# Currently working on 337 - Image id: ISIC_0000409
# Currently working on 338 - Image id: ISIC_0000410
# Currently working on 339 - Image id: ISIC_0000412
# Currently working on 340 - Image id: ISIC_0000413
# Currently working on 341 - Image id: ISIC_0000415
# Currently working on 342 - Image id: ISIC_0000416
# Currently working on 343 - Image id: ISIC_0000418
# Currently working on 344 - Image id: ISIC_0000419
# Currently working on 345 - Image id: ISIC_0000420
# Currently working on 346 - Image id: ISIC_0000421
# Currently working on 347 - Image id: ISIC_0000423
# Currently working on 348 - Image id: ISIC_0000425
# Currently working on 349 - Image id: ISIC_0000426
# Currently working on 350 - Image id: ISIC_0000427
# Currently working on 351 - Image id: ISIC_0000431
# Currently working on 352 - Image id: ISIC_0000433
# Currently working on 353 - Image id: ISIC_0000434
# Currently working on 354 - Image id: ISIC_0000436
# Currently working on 355 - Image id: ISIC_0000439
# Currently working on 356 - Image id: ISIC_0000442
# Currently working on 357 - Image id: ISIC_0000443
# Currently working on 358 - Image id: ISIC_0000444
# Currently working on 359 - Image id: ISIC_0000445
# Currently working on 360 - Image id: ISIC_0000447
# Currently working on 361 - Image id: ISIC_0000448
# Currently working on 362 - Image id: ISIC_0000449
# Currently working on 363 - Image id: ISIC_0000451
# Currently working on 364 - Image id: ISIC_0000453
# Currently working on 365 - Image id: ISIC_0000455
# Currently working on 366 - Image id: ISIC_0000456
# Currently working on 367 - Image id: ISIC_0000457
# Currently working on 368 - Image id: ISIC_0000458
# Currently working on 369 - Image id: ISIC_0000460
# Currently working on 370 - Image id: ISIC_0000461
# Currently working on 371 - Image id: ISIC_0000463
# Currently working on 372 - Image id: ISIC_0000465
# Currently working on 373 - Image id: ISIC_0000466
# Currently working on 374 - Image id: ISIC_0000467
# Currently working on 375 - Image id: ISIC_0000468
# Currently working on 376 - Image id: ISIC_0000469
# Currently working on 377 - Image id: ISIC_0000470
# Currently working on 378 - Image id: ISIC_0000471
# Currently working on 379 - Image id: ISIC_0000473
# Currently working on 380 - Image id: ISIC_0000474
# Currently working on 381 - Image id: ISIC_0000475
# Currently working on 382 - Image id: ISIC_0000476
# Currently working on 383 - Image id: ISIC_0000478
# Currently working on 384 - Image id: ISIC_0000479
# Currently working on 451 - Image id: ISIC_0000551
# Currently working on 452 - Image id: ISIC_0000552
# Currently working on 453 - Image id: ISIC_0000554
# Currently working on 454 - Image id: ISIC_0000555
# Currently working on 455 - Image id: ISIC_0000556
# Currently working on 456 - Image id: ISIC_0000882
# Currently working on 457 - Image id: ISIC_0000900
# Currently working on 458 - Image id: ISIC_0000999
# Currently working on 459 - Image id: ISIC_0001100
# Currently working on 460 - Image id: ISIC_0001102
# Currently working on 461 - Image id: ISIC_0001103
# Currently working on 462 - Image id: ISIC_0001105
# Currently working on 463 - Image id: ISIC_0001118
# Currently working on 464 - Image id: ISIC_0001119
# Currently working on 465 - Image id: ISIC_0001126
# Currently working on 466 - Image id: ISIC_0001128
# Currently working on 467 - Image id: ISIC_0001131
# Currently working on 468 - Image id: ISIC_0001133
# Currently working on 469 - Image id: ISIC_0001134
# Currently working on 470 - Image id: ISIC_0001140
# Currently working on 471 - Image id: ISIC_0001142
# Currently working on 472 - Image id: ISIC_0001148
# Currently working on 473 - Image id: ISIC_0001152
# Currently working on 474 - Image id: ISIC_0001960
# Currently working on 475 - Image id: ISIC_0002093
# Currently working on 476 - Image id: ISIC_0002107
# Currently working on 477 - Image id: ISIC_0002206
# Currently working on 478 - Image id: ISIC_0002246
# Currently working on 479 - Image id: ISIC_0002251
# Currently working on 480 - Image id: ISIC_0002287
# Currently working on 481 - Image id: ISIC_0002353
# Currently working on 482 - Image id: ISIC_0002374
# Currently working on 483 - Image id: ISIC_0002438
# Currently working on 484 - Image id: ISIC_0002439
# Currently working on 485 - Image id: ISIC_0002453
# Currently working on 486 - Image id: ISIC_0002459
# Currently working on 487 - Image id: ISIC_0002469
# Currently working on 488 - Image id: ISIC_0002476
# Currently working on 489 - Image id: ISIC_0002488
# Currently working on 490 - Image id: ISIC_0002489
# Currently working on 491 - Image id: ISIC_0002616
# Currently working on 492 - Image id: ISIC_0002647
# Currently working on 493 - Image id: ISIC_0002673
# Currently working on 494 - Image id: ISIC_0002780
# Currently working on 495 - Image id: ISIC_0002806
# Currently working on 496 - Image id: ISIC_0002829
# Currently working on 497 - Image id: ISIC_0002836
# Currently working on 498 - Image id: ISIC_0002871
# Currently working on 499 - Image id: ISIC_0002879
# Currently working on 500 - Image id: ISIC_0002885
# Currently working on 501 - Image id: ISIC_0002948
# Currently working on 502 - Image id: ISIC_0002975
# Currently working on 503 - Image id: ISIC_0002976
# Currently working on 504 - Image id: ISIC_0003005
# Currently working on 505 - Image id: ISIC_0003051
# Currently working on 506 - Image id: ISIC_0003056
# Currently working on 507 - Image id: ISIC_0003174
# Currently working on 508 - Image id: ISIC_0003308
# Currently working on 509 - Image id: ISIC_0003346
# Currently working on 510 - Image id: ISIC_0003728
# Currently working on 511 - Image id: ISIC_0004110
# Currently working on 512 - Image id: ISIC_0004115
# Currently working on 513 - Image id: ISIC_0004166
# Currently working on 514 - Image id: ISIC_0004168
# Currently working on 515 - Image id: ISIC_0004309
# Currently working on 516 - Image id: ISIC_0004346
# Currently working on 517 - Image id: ISIC_0004715
# Currently working on 518 - Image id: ISIC_0004985
# Currently working on 519 - Image id: ISIC_0005000
# Currently working on 520 - Image id: ISIC_0005187
# Currently working on 521 - Image id: ISIC_0005548
# Currently working on 522 - Image id: ISIC_0005555
# Currently working on 523 - Image id: ISIC_0005620
# Currently working on 524 - Image id: ISIC_0005639
# Currently working on 525 - Image id: ISIC_0005666
# Currently working on 526 - Image id: ISIC_0005787
# Currently working on 527 - Image id: ISIC_0006021
# Currently working on 528 - Image id: ISIC_0006114
# Currently working on 529 - Image id: ISIC_0006193
# Currently working on 530 - Image id: ISIC_0006326
# Currently working on 531 - Image id: ISIC_0006350
# Currently working on 532 - Image id: ISIC_0006612
# Currently working on 533 - Image id: ISIC_0006711
# Currently working on 534 - Image id: ISIC_0006776
# Currently working on 535 - Image id: ISIC_0006795
# Currently working on 536 - Image id: ISIC_0006800
# Currently working on 537 - Image id: ISIC_0006940
# Currently working on 538 - Image id: ISIC_0006982
# Currently working on 539 - Image id: ISIC_0007038
# Currently working on 540 - Image id: ISIC_0007087
# Currently working on 541 - Image id: ISIC_0007322
# Currently working on 542 - Image id: ISIC_0007475
# Currently working on 543 - Image id: ISIC_0007557
# Currently working on 544 - Image id: ISIC_0007693
# Currently working on 545 - Image id: ISIC_0007760
# Currently working on 546 - Image id: ISIC_0008029
# Currently working on 547 - Image id: ISIC_0008116
# Currently working on 548 - Image id: ISIC_0008145
# Currently working on 549 - Image id: ISIC_0008207
# Currently working on 550 - Image id: ISIC_0008236
# Currently working on 551 - Image id: ISIC_0008256
# Currently working on 552 - Image id: ISIC_0008280
# Currently working on 553 - Image id: ISIC_0008294
# Currently working on 554 - Image id: ISIC_0008347
# Currently working on 555 - Image id: ISIC_0008396
# Currently working on 556 - Image id: ISIC_0008403
# Currently working on 557 - Image id: ISIC_0008406
# Currently working on 558 - Image id: ISIC_0008507
# Currently working on 559 - Image id: ISIC_0008528
# Currently working on 560 - Image id: ISIC_0008541
# Currently working on 561 - Image id: ISIC_0008552
# Currently working on 562 - Image id: ISIC_0008600
# Currently working on 563 - Image id: ISIC_0008626
# Currently working on 564 - Image id: ISIC_0008659
# Currently working on 565 - Image id: ISIC_0008785
# Currently working on 566 - Image id: ISIC_0008807
# Currently working on 567 - Image id: ISIC_0008879
# Currently working on 568 - Image id: ISIC_0008992
# Currently working on 569 - Image id: ISIC_0008993
# Currently working on 570 - Image id: ISIC_0008998
# Currently working on 571 - Image id: ISIC_0009035
# Currently working on 572 - Image id: ISIC_0009078
# Currently working on 573 - Image id: ISIC_0009083
# Currently working on 574 - Image id: ISIC_0009160
# Currently working on 575 - Image id: ISIC_0009165
# Currently working on 576 - Image id: ISIC_0009188
# Currently working on 577 - Image id: ISIC_0009252
# Currently working on 578 - Image id: ISIC_0009297
# Currently working on 579 - Image id: ISIC_0009298
# Currently working on 580 - Image id: ISIC_0009344
# Currently working on 581 - Image id: ISIC_0009430
# Currently working on 713 - Image id: ISIC_0010057
# Currently working on 714 - Image id: ISIC_0010058
# Currently working on 715 - Image id: ISIC_0010059
# Currently working on 716 - Image id: ISIC_0010060
# Currently working on 717 - Image id: ISIC_0010061
# Currently working on 718 - Image id: ISIC_0010062
# Currently working on 719 - Image id: ISIC_0010063
# Currently working on 720 - Image id: ISIC_0010064
# Currently working on 721 - Image id: ISIC_0010066
# Currently working on 722 - Image id: ISIC_0010067
# Currently working on 723 - Image id: ISIC_0010069
# Currently working on 724 - Image id: ISIC_0010070
# Currently working on 725 - Image id: ISIC_0010074
# Currently working on 726 - Image id: ISIC_0010075
# Currently working on 727 - Image id: ISIC_0010077
# Currently working on 728 - Image id: ISIC_0010078
# Currently working on 729 - Image id: ISIC_0010080
# Currently working on 730 - Image id: ISIC_0010081
# Currently working on 731 - Image id: ISIC_0010086
# Currently working on 732 - Image id: ISIC_0010087
# Currently working on 733 - Image id: ISIC_0010088
# Currently working on 734 - Image id: ISIC_0010089
# Currently working on 735 - Image id: ISIC_0010090
# Currently working on 736 - Image id: ISIC_0010092
# Currently working on 737 - Image id: ISIC_0010093
# Currently working on 738 - Image id: ISIC_0010094
# Currently working on 739 - Image id: ISIC_0010100
# Currently working on 740 - Image id: ISIC_0010102
# Currently working on 741 - Image id: ISIC_0010104
# Currently working on 742 - Image id: ISIC_0010105
# Currently working on 743 - Image id: ISIC_0010168
# Currently working on 744 - Image id: ISIC_0010170
# Currently working on 745 - Image id: ISIC_0010171
# Currently working on 746 - Image id: ISIC_0010173
# Currently working on 747 - Image id: ISIC_0010174
# Currently working on 748 - Image id: ISIC_0010176
# Currently working on 749 - Image id: ISIC_0010177
# Currently working on 750 - Image id: ISIC_0010178
# Currently working on 751 - Image id: ISIC_0010180
# Currently working on 752 - Image id: ISIC_0010182
# Currently working on 753 - Image id: ISIC_0010184
# Currently working on 754 - Image id: ISIC_0010185
# Currently working on 755 - Image id: ISIC_0010186
# Currently working on 756 - Image id: ISIC_0010187
# Currently working on 757 - Image id: ISIC_0010191
# Currently working on 758 - Image id: ISIC_0010192
# Currently working on 759 - Image id: ISIC_0010193
# Currently working on 760 - Image id: ISIC_0010194
# Currently working on 761 - Image id: ISIC_0010201
# Currently working on 762 - Image id: ISIC_0010202
# Currently working on 763 - Image id: ISIC_0010205
# Currently working on 764 - Image id: ISIC_0010206
# Currently working on 765 - Image id: ISIC_0010207
# Currently working on 766 - Image id: ISIC_0010212
# Currently working on 767 - Image id: ISIC_0010213
# Currently working on 768 - Image id: ISIC_0010215
# Currently working on 769 - Image id: ISIC_0010216
# Currently working on 770 - Image id: ISIC_0010219
# Currently working on 771 - Image id: ISIC_0010220
# Currently working on 772 - Image id: ISIC_0010222
# Currently working on 773 - Image id: ISIC_0010225
# Currently working on 774 - Image id: ISIC_0010227
# Currently working on 775 - Image id: ISIC_0010229
# Currently working on 776 - Image id: ISIC_0010231
# Currently working on 777 - Image id: ISIC_0010233
# Currently working on 778 - Image id: ISIC_0010234
# Currently working on 779 - Image id: ISIC_0010236
# Currently working on 780 - Image id: ISIC_0010237
# Currently working on 781 - Image id: ISIC_0010240
# Currently working on 782 - Image id: ISIC_0010241
# Currently working on 783 - Image id: ISIC_0010244
# Currently working on 784 - Image id: ISIC_0010246
# Currently working on 785 - Image id: ISIC_0010247
# Currently working on 786 - Image id: ISIC_0010248
# Currently working on 787 - Image id: ISIC_0010249
# Currently working on 788 - Image id: ISIC_0010251
# Currently working on 789 - Image id: ISIC_0010254
# Currently working on 790 - Image id: ISIC_0010255
# Currently working on 791 - Image id: ISIC_0010256
# Currently working on 792 - Image id: ISIC_0010257
# Currently working on 793 - Image id: ISIC_0010261
# Currently working on 794 - Image id: ISIC_0010262
# Currently working on 795 - Image id: ISIC_0010264
# Currently working on 796 - Image id: ISIC_0010265
# Currently working on 797 - Image id: ISIC_0010267
# Currently working on 798 - Image id: ISIC_0010317
# Currently working on 799 - Image id: ISIC_0010318
# Currently working on 800 - Image id: ISIC_0010320
# Currently working on 801 - Image id: ISIC_0010326
# Currently working on 802 - Image id: ISIC_0010327
# Currently working on 803 - Image id: ISIC_0010329
# Currently working on 804 - Image id: ISIC_0010330
# Currently working on 805 - Image id: ISIC_0010332
# Currently working on 806 - Image id: ISIC_0010333
# Currently working on 807 - Image id: ISIC_0010334
# Currently working on 808 - Image id: ISIC_0010336
# Currently working on 809 - Image id: ISIC_0010337
# Currently working on 810 - Image id: ISIC_0010339
# Currently working on 811 - Image id: ISIC_0010340
# Currently working on 812 - Image id: ISIC_0010341
# Currently working on 813 - Image id: ISIC_0010342
# Currently working on 814 - Image id: ISIC_0010344
# Currently working on 815 - Image id: ISIC_0010346
# Currently working on 816 - Image id: ISIC_0010348
# Currently working on 817 - Image id: ISIC_0010350
# Currently working on 818 - Image id: ISIC_0010351
# Currently working on 819 - Image id: ISIC_0010356
# Currently working on 820 - Image id: ISIC_0010357
# Currently working on 821 - Image id: ISIC_0010358
# Currently working on 822 - Image id: ISIC_0010360
# Currently working on 823 - Image id: ISIC_0010362
# Currently working on 824 - Image id: ISIC_0010364
# Currently working on 825 - Image id: ISIC_0010365
# Currently working on 826 - Image id: ISIC_0010367
# Currently working on 827 - Image id: ISIC_0010368
# Currently working on 828 - Image id: ISIC_0010370
# Currently working on 829 - Image id: ISIC_0010371
# Currently working on 830 - Image id: ISIC_0010372
# Currently working on 831 - Image id: ISIC_0010374
# Currently working on 832 - Image id: ISIC_0010379
# Currently working on 833 - Image id: ISIC_0010382
# Currently working on 834 - Image id: ISIC_0010435
# Currently working on 835 - Image id: ISIC_0010441
# Currently working on 836 - Image id: ISIC_0010442
# Currently working on 837 - Image id: ISIC_0010443
# Currently working on 838 - Image id: ISIC_0010444
# Currently working on 839 - Image id: ISIC_0010447
# Currently working on 840 - Image id: ISIC_0010448
# Currently working on 841 - Image id: ISIC_0010449
# Currently working on 842 - Image id: ISIC_0010452
# Currently working on 843 - Image id: ISIC_0010455
# Currently working on 909 - Image id: ISIC_0010844
# Currently working on 910 - Image id: ISIC_0010846
# Currently working on 911 - Image id: ISIC_0010847
# Currently working on 912 - Image id: ISIC_0010848
# Currently working on 913 - Image id: ISIC_0010850
# Currently working on 914 - Image id: ISIC_0010851
# Currently working on 915 - Image id: ISIC_0010852
# Currently working on 916 - Image id: ISIC_0010853
# Currently working on 917 - Image id: ISIC_0010854
# Currently working on 918 - Image id: ISIC_0010856
# Currently working on 919 - Image id: ISIC_0010857
# Currently working on 920 - Image id: ISIC_0010858
# Currently working on 921 - Image id: ISIC_0010860
# Currently working on 922 - Image id: ISIC_0010861
# Currently working on 923 - Image id: ISIC_0010862
# Currently working on 924 - Image id: ISIC_0010863
# Currently working on 925 - Image id: ISIC_0010864
# Currently working on 926 - Image id: ISIC_0011079
# Currently working on 927 - Image id: ISIC_0011082
# Currently working on 928 - Image id: ISIC_0011083
# Currently working on 929 - Image id: ISIC_0011085
# Currently working on 930 - Image id: ISIC_0011088
# Currently working on 931 - Image id: ISIC_0011089
# Currently working on 932 - Image id: ISIC_0011090
# Currently working on 933 - Image id: ISIC_0011095
# Currently working on 934 - Image id: ISIC_0011097
# Currently working on 935 - Image id: ISIC_0011098
# Currently working on 936 - Image id: ISIC_0011099
# Currently working on 937 - Image id: ISIC_0011101
# Currently working on 938 - Image id: ISIC_0011102
# Currently working on 939 - Image id: ISIC_0011107
# Currently working on 940 - Image id: ISIC_0011110
# Currently working on 941 - Image id: ISIC_0011112
# Currently working on 942 - Image id: ISIC_0011114
# Currently working on 943 - Image id: ISIC_0011115
# Currently working on 944 - Image id: ISIC_0011117
# Currently working on 945 - Image id: ISIC_0011118
# Currently working on 946 - Image id: ISIC_0011119
# Currently working on 947 - Image id: ISIC_0011121
# Currently working on 948 - Image id: ISIC_0011123
# Currently working on 949 - Image id: ISIC_0011124
# Currently working on 950 - Image id: ISIC_0011126
# Currently working on 951 - Image id: ISIC_0011127
# Currently working on 952 - Image id: ISIC_0011130
# Currently working on 953 - Image id: ISIC_0011131
# Currently working on 954 - Image id: ISIC_0011132
# Currently working on 955 - Image id: ISIC_0011135
# Currently working on 956 - Image id: ISIC_0011136
# Currently working on 957 - Image id: ISIC_0011137
# Currently working on 958 - Image id: ISIC_0011140
# Currently working on 959 - Image id: ISIC_0011143
# Currently working on 960 - Image id: ISIC_0011144
# Currently working on 961 - Image id: ISIC_0011145
# ...
# Currently working on 1687 - Image id: ISIC_0014072
# Currently working on 1688 - Image id: ISIC_0014073
# Currently working on 1689 - Image id: ISIC_0014074
# Currently working on 1690 - Image id: ISIC_0014076
# Currently working on 1691 - Image id: ISIC_0014079
# Currently working on 1692 - Image id: ISIC_0014080
# Currently working on 1693 - Image id: ISIC_0014081
# Currently working on 1694 - Image id: ISIC_0014082
# Currently working on 1695 - Image id: ISIC_0014083
# Currently working on 1696 - Image id: ISIC_0014088
# Currently working on 1697 - Image id: ISIC_0014089
# Currently working on 1698 - Image id: ISIC_0014092
# Currently working on 1699 - Image id: ISIC_0014093
# Currently working on 1700 - Image id: ISIC_0014094
# Currently working on 1701 - Image id: ISIC_0014099
# Currently working on 1702 - Image id: ISIC_0014108
# Currently working on 1703 - Image id: ISIC_0014114
# Currently working on 1704 - Image id: ISIC_0014120
# Currently working on 1705 - Image id: ISIC_0014127
# Currently working on 1706 - Image id: ISIC_0014131
# Currently working on 1707 - Image id: ISIC_0014132
# Currently working on 1708 - Image id: ISIC_0014133
# Currently working on 1709 - Image id: ISIC_0014136
# Currently working on 1710 - Image id: ISIC_0014144
# Currently working on 1711 - Image id: ISIC_0014149
# Currently working on 1712 - Image id: ISIC_0014150
# Currently working on 1713 - Image id: ISIC_0014151
# Currently working on 1714 - Image id: ISIC_0014156
# Currently working on 1715 - Image id: ISIC_0014157
# Currently working on 1716 - Image id: ISIC_0014158
# Currently working on 1717 - Image id: ISIC_0014163
# Currently working on 1718 - Image id: ISIC_0014164
# Currently working on 1719 - Image id: ISIC_0014166
# Currently working on 1720 - Image id: ISIC_0014169
# Currently working on 1721 - Image id: ISIC_0014171
# Currently working on 1722 - Image id: ISIC_0014173
# Currently working on 1723 - Image id: ISIC_0014174
# Currently working on 1724 - Image id: ISIC_0014179
# Currently working on 1725 - Image id: ISIC_0014183
# Currently working on 1726 - Image id: ISIC_0014185
# Currently working on 1727 - Image id: ISIC_0014187
# Currently working on 1728 - Image id: ISIC_0014189
# Currently working on 1729 - Image id: ISIC_0014190
# Currently working on 1730 - Image id: ISIC_0014191
# Currently working on 1731 - Image id: ISIC_0014195
# Currently working on 1732 - Image id: ISIC_0014197
# Currently working on 1733 - Image id: ISIC_0014216
# Currently working on 1734 - Image id: ISIC_0014222
# Currently working on 1735 - Image id: ISIC_0014225
# Currently working on 1736 - Image id: ISIC_0014229
# Currently working on 1737 - Image id: ISIC_0014238
# Currently working on 1738 - Image id: ISIC_0014248
# Currently working on 1739 - Image id: ISIC_0014249
# Currently working on 1740 - Image id: ISIC_0014253
# Currently working on 1741 - Image id: ISIC_0014263
# Currently working on 1742 - Image id: ISIC_0014264
# Currently working on 1743 - Image id: ISIC_0014272
# Currently working on 1744 - Image id: ISIC_0014273
# Currently working on 1745 - Image id: ISIC_0014274
# Currently working on 1746 - Image id: ISIC_0014286
# Currently working on 1747 - Image id: ISIC_0014289
# Currently working on 1748 - Image id: ISIC_0014290
# Currently working on 1749 - Image id: ISIC_0014291
# Currently working on 1750 - Image id: ISIC_0014299
# Currently working on 1751 - Image id: ISIC_0014308
# Currently working on 1752 - Image id: ISIC_0014311
# Currently working on 1753 - Image id: ISIC_0014316
# Currently working on 1754 - Image id: ISIC_0014317
# Currently working on 1755 - Image id: ISIC_0014324
# Currently working on 1756 - Image id: ISIC_0014325
# Currently working on 1757 - Image id: ISIC_0014327
# Currently working on 1758 - Image id: ISIC_0014328
# Currently working on 1759 - Image id: ISIC_0014331
# Currently working on 1760 - Image id: ISIC_0014337
# Currently working on 1761 - Image id: ISIC_0014341
# Currently working on 1762 - Image id: ISIC_0014346
# Currently working on 1763 - Image id: ISIC_0014347
# Currently working on 1764 - Image id: ISIC_0014353
# Currently working on 1765 - Image id: ISIC_0014357
# Currently working on 1766 - Image id: ISIC_0014360
# Currently working on 1767 - Image id: ISIC_0014361
# Currently working on 1768 - Image id: ISIC_0014365
# Currently working on 1769 - Image id: ISIC_0014366
# Currently working on 1770 - Image id: ISIC_0014372
# Currently working on 1771 - Image id: ISIC_0014385
# Currently working on 1772 - Image id: ISIC_0014393
# Currently working on 1773 - Image id: ISIC_0014394
# Currently working on 1774 - Image id: ISIC_0014395
# Currently working on 1775 - Image id: ISIC_0014397
# Currently working on 1776 - Image id: ISIC_0014410
# Currently working on 1777 - Image id: ISIC_0014422
# Currently working on 1778 - Image id: ISIC_0014430
# Currently working on 1779 - Image id: ISIC_0014431
# Currently working on 1780 - Image id: ISIC_0014432
# Currently working on 1781 - Image id: ISIC_0014433
# Currently working on 1782 - Image id: ISIC_0014438
# Currently working on 1783 - Image id: ISIC_0014440
# Currently working on 1784 - Image id: ISIC_0014441
# Currently working on 1785 - Image id: ISIC_0014453
# Currently working on 1786 - Image id: ISIC_0014458
# Currently working on 1787 - Image id: ISIC_0014469
# Currently working on 1788 - Image id: ISIC_0014473
# Currently working on 1789 - Image id: ISIC_0014475
# Currently working on 1790 - Image id: ISIC_0014476
# Currently working on 1791 - Image id: ISIC_0014480
# Currently working on 1792 - Image id: ISIC_0014486
# Currently working on 1793 - Image id: ISIC_0014490
# Currently working on 1794 - Image id: ISIC_0014498
# Currently working on 1795 - Image id: ISIC_0014501
# Currently working on 1796 - Image id: ISIC_0014502
# Currently working on 1797 - Image id: ISIC_0014504
# Currently working on 1798 - Image id: ISIC_0014507
# Currently working on 1799 - Image id: ISIC_0014511
# Currently working on 1800 - Image id: ISIC_0014515
# Currently working on 1801 - Image id: ISIC_0014516
# Currently working on 1802 - Image id: ISIC_0014518
# Currently working on 1803 - Image id: ISIC_0014522
# Currently working on 1804 - Image id: ISIC_0014525
# Currently working on 1805 - Image id: ISIC_0014526
# Currently working on 1806 - Image id: ISIC_0014527
# Currently working on 1807 - Image id: ISIC_0014529
# Currently working on 1808 - Image id: ISIC_0014535
# Currently working on 1809 - Image id: ISIC_0014537
# Currently working on 1810 - Image id: ISIC_0014543
# Currently working on 1811 - Image id: ISIC_0014545
# Currently working on 1812 - Image id: ISIC_0014547
# Currently working on 1813 - Image id: ISIC_0014554
# Currently working on 1814 - Image id: ISIC_0014557
# Currently working on 1815 - Image id: ISIC_0014569
# Currently working on 1816 - Image id: ISIC_0014570
# Currently working on 1817 - Image id: ISIC_0014571
# Currently working on 1818 - Image id: ISIC_0014573
# Currently working on 1819 - Image id: ISIC_0014576
# Currently working on 1820 - Image id: ISIC_0014577
# Currently working on 1821 - Image id: ISIC_0014578
# Currently working on 1822 - Image id: ISIC_0014579
# Currently working on 1823 - Image id: ISIC_0014580
# Currently working on 1824 - Image id: ISIC_0014581
# Currently working on 1825 - Image id: ISIC_0014582
# Currently working on 1826 - Image id: ISIC_0014583
# Currently working on 1827 - Image id: ISIC_0014585
# Currently working on 1828 - Image id: ISIC_0014589
# Currently working on 1829 - Image id: ISIC_0014591
# Currently working on 1830 - Image id: ISIC_0014592
# Currently working on 1831 - Image id: ISIC_0014593
# Currently working on 1832 - Image id: ISIC_0014594
# Currently working on 1833 - Image id: ISIC_0014595
# Currently working on 1834 - Image id: ISIC_0014596
# Currently working on 1835 - Image id: ISIC_0014598
# Currently working on 1836 - Image id: ISIC_0014599
# Currently working on 1837 - Image id: ISIC_0014602
# Currently working on 1838 - Image id: ISIC_0014603
# Currently working on 1839 - Image id: ISIC_0014605
# Currently working on 1840 - Image id: ISIC_0014606
# Currently working on 1841 - Image id: ISIC_0014607
# Currently working on 1842 - Image id: ISIC_0014609
# Currently working on 1843 - Image id: ISIC_0014612
# Currently working on 1844 - Image id: ISIC_0014613
# Currently working on 1845 - Image id: ISIC_0014615
# Currently working on 1846 - Image id: ISIC_0014617
# Currently working on 1847 - Image id: ISIC_0014621
# Currently working on 1848 - Image id: ISIC_0014622
# Currently working on 1849 - Image id: ISIC_0014625
# Currently working on 1850 - Image id: ISIC_0014628
# Currently working on 1851 - Image id: ISIC_0014630
# Currently working on 1852 - Image id: ISIC_0014632
# Currently working on 1853 - Image id: ISIC_0014636
# Currently working on 1854 - Image id: ISIC_0014638
# Currently working on 1855 - Image id: ISIC_0014639
# Currently working on 1856 - Image id: ISIC_0014640
# Currently working on 1857 - Image id: ISIC_0014641
# Currently working on 1858 - Image id: ISIC_0014642
# Currently working on 1859 - Image id: ISIC_0014646
# Currently working on 1860 - Image id: ISIC_0014650
# Currently working on 1861 - Image id: ISIC_0014651
# Currently working on 1862 - Image id: ISIC_0014654
# Currently working on 1863 - Image id: ISIC_0014657
# Currently working on 1864 - Image id: ISIC_0014658
# Currently working on 1865 - Image id: ISIC_0014661
# Currently working on 1866 - Image id: ISIC_0014664
# Currently working on 1867 - Image id: ISIC_0014665
# Currently working on 1868 - Image id: ISIC_0014667
# Currently working on 1869 - Image id: ISIC_0014680
# Currently working on 1870 - Image id: ISIC_0014682
# Currently working on 1871 - Image id: ISIC_0014683
# Currently working on 1872 - Image id: ISIC_0014684
# Currently working on 1873 - Image id: ISIC_0014685
# Currently working on 1874 - Image id: ISIC_0014692
# Currently working on 1875 - Image id: ISIC_0014694
# Currently working on 1876 - Image id: ISIC_0014696
# Currently working on 1877 - Image id: ISIC_0014699
# Currently working on 1878 - Image id: ISIC_0014702
# Currently working on 1879 - Image id: ISIC_0014707
# Currently working on 1880 - Image id: ISIC_0014708
# Currently working on 1881 - Image id: ISIC_0014711
# Currently working on 1882 - Image id: ISIC_0014713
# Currently working on 1883 - Image id: ISIC_0014714
# Currently working on 1884 - Image id: ISIC_0014715
# Currently working on 1885 - Image id: ISIC_0014716
# Currently working on 1886 - Image id: ISIC_0014722
# Currently working on 1887 - Image id: ISIC_0014723
# Currently working on 1888 - Image id: ISIC_0014724
# Currently working on 1889 - Image id: ISIC_0014726
# Currently working on 1890 - Image id: ISIC_0014730
# Currently working on 1891 - Image id: ISIC_0014731
# Currently working on 1892 - Image id: ISIC_0014735
# Currently working on 1893 - Image id: ISIC_0014739
# Currently working on 1894 - Image id: ISIC_0014742
# Currently working on 1895 - Image id: ISIC_0014745
# Currently working on 1896 - Image id: ISIC_0014748
# Currently working on 1897 - Image id: ISIC_0014754
# Currently working on 1898 - Image id: ISIC_0014760
# Currently working on 1899 - Image id: ISIC_0014762
# Currently working on 1900 - Image id: ISIC_0014763
# Currently working on 1901 - Image id: ISIC_0014769
# Currently working on 1902 - Image id: ISIC_0014770
# Currently working on 1903 - Image id: ISIC_0014771
# Currently working on 1904 - Image id: ISIC_0014775
# Currently working on 1905 - Image id: ISIC_0014778
# Currently working on 1906 - Image id: ISIC_0014779
# Currently working on 1907 - Image id: ISIC_0014782
# Currently working on 1908 - Image id: ISIC_0014783
# Currently working on 1909 - Image id: ISIC_0014785
# Currently working on 1910 - Image id: ISIC_0014788
# Currently working on 1911 - Image id: ISIC_0014791
# Currently working on 1912 - Image id: ISIC_0014793
# Currently working on 1913 - Image id: ISIC_0014794
# Currently working on 1914 - Image id: ISIC_0014795
# Currently working on 1915 - Image id: ISIC_0014797
# Currently working on 1916 - Image id: ISIC_0014802
# Currently working on 1917 - Image id: ISIC_0014803
# Currently working on 1918 - Image id: ISIC_0014804
# Currently working on 1919 - Image id: ISIC_0014805
# Currently working on 1920 - Image id: ISIC_0014806
# Currently working on 1921 - Image id: ISIC_0014808
# Currently working on 1922 - Image id: ISIC_0014811
# Currently working on 1923 - Image id: ISIC_0014812
# Currently working on 1924 - Image id: ISIC_0014818
# Currently working on 1925 - Image id: ISIC_0014819
# Currently working on 1926 - Image id: ISIC_0014821
# Currently working on 1927 - Image id: ISIC_0014823
# Currently working on 1928 - Image id: ISIC_0014825
# Currently working on 1929 - Image id: ISIC_0014830
# Currently working on 1930 - Image id: ISIC_0014831
# Currently working on 1931 - Image id: ISIC_0014832
# Currently working on 1932 - Image id: ISIC_0014834
# Currently working on 1933 - Image id: ISIC_0014836
# Currently working on 1934 - Image id: ISIC_0014838
# Currently working on 1935 - Image id: ISIC_0014839
# Currently working on 1936 - Image id: ISIC_0014843
# Currently working on 1937 - Image id: ISIC_0014845
# Currently working on 1938 - Image id: ISIC_0014846
# Currently working on 1939 - Image id: ISIC_0014848
# Currently working on 1940 - Image id: ISIC_0014849
# Currently working on 1941 - Image id: ISIC_0014850
# Currently working on 1942 - Image id: ISIC_0014851
# Currently working on 1943 - Image id: ISIC_0014855
# Currently working on 1944 - Image id: ISIC_0014860
# Currently working on 1945 - Image id: ISIC_0014866
# Currently working on 1946 - Image id: ISIC_0014869
# Currently working on 1947 - Image id: ISIC_0014890
# Currently working on 1948 - Image id: ISIC_0014891
# Currently working on 1949 - Image id: ISIC_0014897
# Currently working on 1950 - Image id: ISIC_0014898
# Currently working on 1951 - Image id: ISIC_0014903
# Currently working on 1952 - Image id: ISIC_0014904
# Currently working on 1953 - Image id: ISIC_0014908
# Currently working on 1954 - Image id: ISIC_0014911
# Currently working on 1955 - Image id: ISIC_0014913
# Currently working on 1956 - Image id: ISIC_0014915
# Currently working on 1957 - Image id: ISIC_0014919
# Currently working on 1958 - Image id: ISIC_0014920
# Currently working on 1959 - Image id: ISIC_0014922
# Currently working on 1960 - Image id: ISIC_0014923
# Currently working on 1961 - Image id: ISIC_0014925
# Currently working on 1962 - Image id: ISIC_0014926
# Currently working on 1963 - Image id: ISIC_0014929
# Currently working on 1964 - Image id: ISIC_0014930
# Currently working on 1965 - Image id: ISIC_0014933
# Currently working on 1966 - Image id: ISIC_0014951
# Currently working on 1967 - Image id: ISIC_0014975
# Currently working on 1968 - Image id: ISIC_0014983
# Currently working on 1969 - Image id: ISIC_0014987
# Currently working on 1970 - Image id: ISIC_0015005
# Currently working on 1971 - Image id: ISIC_0015006
# Currently working on 1972 - Image id: ISIC_0015032
# Currently working on 1973 - Image id: ISIC_0015038
# Currently working on 1974 - Image id: ISIC_0015044
# Currently working on 1975 - Image id: ISIC_0015045
# Currently working on 1976 - Image id: ISIC_0015079
# Currently working on 1977 - Image id: ISIC_0015082
# Currently working on 1978 - Image id: ISIC_0015108
# Currently working on 1979 - Image id: ISIC_0015109
# Currently working on 1980 - Image id: ISIC_0015110
# Currently working on 1981 - Image id: ISIC_0015112
# Currently working on 1982 - Image id: ISIC_0015113
# Currently working on 1983 - Image id: ISIC_0015153
# Currently working on 1984 - Image id: ISIC_0015158
# Currently working on 1985 - Image id: ISIC_0015166
# Currently working on 1986 - Image id: ISIC_0015168
# Currently working on 1987 - Image id: ISIC_0015170
# Currently working on 1988 - Image id: ISIC_0015181
# Currently working on 1989 - Image id: ISIC_0015182
# Currently working on 1990 - Image id: ISIC_0015189
# Currently working on 1991 - Image id: ISIC_0015190
# Currently working on 1992 - Image id: ISIC_0015200
# Currently working on 1993 - Image id: ISIC_0015204
# Currently working on 1994 - Image id: ISIC_0015219
# Currently working on 1995 - Image id: ISIC_0015220
# Currently working on 1996 - Image id: ISIC_0015233
# Currently working on 1997 - Image id: ISIC_0015260
# Currently working on 1998 - Image id: ISIC_0015284
# Currently working on 1999 - Image id: ISIC_0015295

# %%
feature_scales = pd.DataFrame([features['perimeter_1'],
                                features['perimeter_2'],
                                features['perimeter_3'],
                                features['perimeter_4'],
                                features['compactness_1'],
                                features['compactness_2'],
                                features['compactness_3'],
                                features['compactness_4']])

# %%
feature_scales = feature_scales.transpose()
feature_scales.describe()
# Out:
#         perimeter_1   perimeter_2  perimeter_3    perimeter_4  compactness_1  \
# count   2000.000000   2000.000000   2000.00000    2000.000000    2000.000000
# mean    3304.243000   6534.197000  10053.41300   13237.224500       1.351726
# std     3549.302668   6886.838111  10335.74022   13553.218592       1.676975
# min      317.000000    632.000000   1007.00000    1317.000000       0.088357
# 25%     1434.000000   2852.000000   4488.50000    5928.750000       0.833657
# 50%     2143.000000   4260.500000   6622.50000    8744.000000       1.040209
# 75%     3594.500000   7159.500000  11179.75000   14684.750000       1.391115
# max    35203.000000  65235.000000  98278.00000  123997.000000      35.137359
#
#        compactness_2  compactness_3  compactness_4
# count    2000.000000    2000.000000    2000.000000
# mean        5.161827      12.291431      21.054818
# std         5.270066      11.407258      17.767377
# min         0.354235       0.875832       1.527257
# 25%         3.333039       8.189498      14.247109
# 50%         4.147590      10.036135      17.546806
# 75%         5.498148      13.155825      22.918351
# max       104.152494     216.949080     330.227809

# %%
feature_scales['p_1_2'] = feature_scales['perimeter_2'] / feature_scales['perimeter_1']
feature_scales['p_2_3'] = feature_scales['perimeter_3'] / feature_scales['perimeter_2']
feature_scales['p_3_4'] = feature_scales['perimeter_4'] / feature_scales['perimeter_3']
feature_scales['p_1_3'] = feature_scales['perimeter_3'] / feature_scales['perimeter_1']
feature_scales['p_2_4'] = feature_scales['perimeter_4'] / feature_scales['perimeter_2']
feature_scales['p_1_4'] = feature_scales['perimeter_4'] / feature_scales['perimeter_1']


feature_scales['c_1_2'] = feature_scales['compactness_2'] / feature_scales['compactness_1']
feature_scales['c_2_3'] = feature_scales['compactness_3'] / feature_scales['compactness_2']
feature_scales['c_3_4'] = feature_scales['compactness_4'] / feature_scales['compactness_3']
feature_scales['c_1_3'] = feature_scales['compactness_3'] / feature_scales['compactness_1']
feature_scales['c_1_4'] = feature_scales['compactness_4'] / feature_scales['compactness_1']
feature_scales['c_2_4'] = feature_scales['compactness_4'] / feature_scales['compactness_2']

# %%
tmp_df = feature_scales.drop(['perimeter_2','perimeter_1','perimeter_3','perimeter_4','compactness_1','compactness_2','compactness_3','compactness_4'],axis=1)
tmp_df.describe()
# Out:
#              p_1_2        p_2_3        p_3_4        p_1_3        p_2_4  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      1.987185     1.553781     1.317382     3.088323     2.046744
# std       0.039361     0.046649     0.015102     0.126566     0.059321
# min       1.707717     1.422143     1.227119     2.428617     1.745811
# 25%       1.989758     1.499762     1.311703     2.987230     1.994772
# 50%       1.993877     1.563194     1.319376     3.123926     2.062527
# 75%       2.000692     1.591553     1.328562     3.175755     2.089428
# max       2.008152     1.688544     1.339787     3.375522     2.188776
#
#              p_1_4        c_1_2        c_2_3        c_3_4        c_1_3  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      4.068837     3.950455     2.416411     1.735724     9.553750
# std       0.176303     0.148953     0.144923     0.039184     0.759123
# min       2.981350     2.916297     2.022490     1.505821     5.898182
# 25%       3.974378     3.959135     2.249287     1.720566     8.923541
# 50%       4.121043     3.975544     2.443575     1.740754     9.758913
# 75%       4.172067     4.002767     2.533040     1.765076    10.085417
# max       4.375522     4.032675     2.851179     1.795029    11.394146
#
#              c_1_4        c_2_4
# count  2000.000000  2000.000000
# mean     16.586499     4.192677
# std       1.350396     0.238885
# min       8.888451     3.047855
# 25%      15.795684     3.979115
# 50%      16.982995     4.254020
# 75%      17.406140     4.365709
# max      19.145189     4.790738
